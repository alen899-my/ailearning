# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("fitness_dataset.csv")

# %%
data.head()
# Out:
#    age  height_cm  weight_kg  heart_rate  blood_pressure  sleep_hours  \
# 0   56        152         65        69.6           117.0          NaN
# 1   69        186         95        60.8           114.8          7.5
# 2   46        192        103        61.4           116.4          NaN
# 3   32        189         83        60.2           130.1          7.0
# 4   60        175         99        58.1           115.8          8.0
#
#    nutrition_quality  activity_index smokes gender  is_fit
# 0               2.37            3.97     no      F       1
# 1               8.77            3.19      0      F       1
# 2               8.20            2.03      0      F       0
# 3               6.18            3.68      0      M       1
# 4               9.95            4.83    yes      F       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                2000 non-null   int64
#  1   height_cm          2000 non-null   int64
#  2   weight_kg          2000 non-null   int64
#  3   heart_rate         2000 non-null   float64
#  4   blood_pressure     2000 non-null   float64
#  5   sleep_hours        1840 non-null   float64
#  6   nutrition_quality  2000 non-null   float64
#  7   activity_index     2000 non-null   float64
#  8   smokes             2000 non-null   object
#  9   gender             2000 non-null   object
#  10  is_fit             2000 non-null   int64
# dtypes: float64(5), int64(4), object(2)
# memory usage: 172.0+ KB

# %%
data.describe()
# Out:
#                age   height_cm    weight_kg   heart_rate  blood_pressure  \
# count  2000.000000  2000.00000  2000.000000  2000.000000     2000.000000
# mean     49.114000   174.53300    83.540500    70.288600      119.908850
# std      17.926564    14.37175    25.852534    11.846339       14.578032
# min      18.000000   150.00000    30.000000    45.000000       90.000000
# 25%      34.000000   162.00000    64.000000    62.100000      109.700000
# 50%      49.000000   174.00000    83.000000    70.250000      120.000000
# 75%      65.000000   187.00000   102.000000    78.425000      129.800000
# max      79.000000   199.00000   250.000000   118.600000      171.200000
#
#        sleep_hours  nutrition_quality  activity_index       is_fit
# count  1840.000000        2000.000000     2000.000000  2000.000000
# mean      7.513315           5.035140        2.999040     0.399500
# std       1.502031           2.864156        1.136383     0.489918
# min       4.000000           0.000000        1.000000     0.000000
# 25%       6.500000           2.547500        2.037500     0.000000
# 50%       7.500000           5.065000        2.980000     0.000000
# 75%       8.600000           7.470000        3.950000     1.000000
# max      12.000000          10.000000        4.990000     1.000000

# %%
data.isnull().sum()
# Out:
# age                    0
# height_cm              0
# weight_kg              0
# heart_rate             0
# blood_pressure         0
# sleep_hours          160
# nutrition_quality      0
# activity_index         0
# smokes                 0
# gender                 0
# is_fit                 0
# dtype: int64

# %%
data["sleep_hours"].unique()
# Out:
# array([ nan,  7.5,  7. ,  8. ,  7.7,  7.4,  6.6,  9.1,  8.1,  5.9,  8.5,
#         8.8,  4.4,  6.2,  6.3,  7.3,  7.8,  5.8,  9.9,  8.6,  7.6,  4.6,
#         7.1, 10. ,  9.5,  8.2,  8.7,  8.9,  6.8,  9. ,  5.7,  9.2, 10.1,
#         7.9,  5.1,  9.3,  6.7,  6.1,  5.6, 11. , 11.1,  7.2,  6.5,  4.7,
#         4.1,  6.9,  4.9, 10.5, 10.9,  8.3,  6. ,  9.4, 11.5,  5.4,  4. ,
#         5. ,  4.8, 10.3,  8.4,  9.8,  9.7,  4.5,  6.4, 10.7,  4.3,  5.5,
#         5.2, 10.8,  5.3, 10.2, 10.4, 11.4,  9.6, 11.3,  4.2, 11.6, 10.6,
#        11.7, 12. , 11.2])

# %%
data["sleep_hours"]=data["sleep_hours"].fillna(data["sleep_hours"].mean())

# %%
data["sleep_hours"].isnull().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# age                  0
# height_cm            0
# weight_kg            0
# heart_rate           0
# blood_pressure       0
# sleep_hours          0
# nutrition_quality    0
# activity_index       0
# smokes               0
# gender               0
# is_fit               0
# dtype: int64

# %%
data.corr
# Out:
# <bound method DataFrame.corr of       age  height_cm  weight_kg  heart_rate  blood_pressure  sleep_hours  \
# 0      56        152         65        69.6           117.0     7.513315
# 1      69        186         95        60.8           114.8     7.500000
# 2      46        192        103        61.4           116.4     7.513315
# 3      32        189         83        60.2           130.1     7.000000
# 4      60        175         99        58.1           115.8     8.000000
# ...   ...        ...        ...         ...             ...          ...
# 1995   52        173         98        60.7           106.1     7.513315
# 1996   61        186         74        51.4           123.8     9.400000
# 1997   77        198         89        76.7           103.6     8.300000
# 1998   62        190         63        80.7           115.9     6.700000
# 1999   51        166         78        89.3           101.8     8.300000
#
#       nutrition_quality  activity_index smokes gender  is_fit
# 0                  2.37            3.97     no      F       1
# 1                  8.77            3.19      0      F       1
# 2                  8.20            2.03      0      F       0
# 3                  6.18            3.68      0      M       1
# 4                  9.95            4.83    yes      F       1
# ...                 ...             ...    ...    ...     ...
# 1995               1.54            3.25      1      M       1
# 1996               8.63            3.15     no      M       1
# 1997               1.98            3.36    yes      M       0
# 1998               9.21            2.39      1      F       0
# 1999               4.42            1.02      1      M       0
#
# [2000 rows x 11 columns]>

# %%
data.head()
# Out:
#    age  height_cm  weight_kg  heart_rate  blood_pressure  sleep_hours  \
# 0   56        152         65        69.6           117.0     7.513315
# 1   69        186         95        60.8           114.8     7.500000
# 2   46        192        103        61.4           116.4     7.513315
# 3   32        189         83        60.2           130.1     7.000000
# 4   60        175         99        58.1           115.8     8.000000
#
#    nutrition_quality  activity_index smokes gender  is_fit
# 0               2.37            3.97     no      F       1
# 1               8.77            3.19      0      F       1
# 2               8.20            2.03      0      F       0
# 3               6.18            3.68      0      M       1
# 4               9.95            4.83    yes      F       1

# %%
data["smokes"].unique()
# Out:
# array(['no', '0', 'yes', '1'], dtype=object)

# %%
data["smokes"]=data["smokes"].replace({
    "no":0,
    "yes":1,
    "0":0,
    "1":1
}).astype(int)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11744\3435464267.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["smokes"]=data["smokes"].replace({

# %%
data["smokes"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1995    1
# 1996    0
# 1997    1
# 1998    1
# 1999    1
# Name: smokes, Length: 2000, dtype: int64

# %%
data["gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le1=LabelEncoder()
data["gender"]=le1.fit_transform(data["gender"])

# %%
data["smokes"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1995    1
# 1996    0
# 1997    1
# 1998    1
# 1999    1
# Name: smokes, Length: 2000, dtype: int64

# %%
data.head()
# Out:
#    age  height_cm  weight_kg  heart_rate  blood_pressure  sleep_hours  \
# 0   56        152         65        69.6           117.0     7.513315
# 1   69        186         95        60.8           114.8     7.500000
# 2   46        192        103        61.4           116.4     7.513315
# 3   32        189         83        60.2           130.1     7.000000
# 4   60        175         99        58.1           115.8     8.000000
#
#    nutrition_quality  activity_index  smokes  gender  is_fit
# 0               2.37            3.97       0       0       1
# 1               8.77            3.19       0       0       1
# 2               8.20            2.03       0       0       0
# 3               6.18            3.68       0       1       1
# 4               9.95            4.83       1       0       1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(data.corr() , annot=True)
plt.show()

# %%
X=data.drop("is_fit",axis=1)

# %%
X
# Out:
#       age  height_cm  weight_kg  heart_rate  blood_pressure  sleep_hours  \
# 0      56        152         65        69.6           117.0     7.513315
# 1      69        186         95        60.8           114.8     7.500000
# 2      46        192        103        61.4           116.4     7.513315
# 3      32        189         83        60.2           130.1     7.000000
# 4      60        175         99        58.1           115.8     8.000000
# ...   ...        ...        ...         ...             ...          ...
# 1995   52        173         98        60.7           106.1     7.513315
# 1996   61        186         74        51.4           123.8     9.400000
# 1997   77        198         89        76.7           103.6     8.300000
# 1998   62        190         63        80.7           115.9     6.700000
# 1999   51        166         78        89.3           101.8     8.300000
#
#       nutrition_quality  activity_index  smokes  gender
# 0                  2.37            3.97       0       0
# 1                  8.77            3.19       0       0
# 2                  8.20            2.03       0       0
# 3                  6.18            3.68       0       1
# 4                  9.95            4.83       1       0
# ...                 ...             ...     ...     ...
# 1995               1.54            3.25       1       1
# 1996               8.63            3.15       0       1
# 1997               1.98            3.36       1       1
# 1998               9.21            2.39       1       0
# 1999               4.42            1.02       1       1
#
# [2000 rows x 10 columns]

# %%
y=data["is_fit"]

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X,y )
importance = model.coef_[0]

for col, imp in zip(X.columns, importance):
    print(col, imp)
# Out:
# age -0.03934593879762329
# height_cm 0.012299654324135918
# weight_kg -0.007048103241130143
# heart_rate 0.004450577736672327
# blood_pressure -0.014637359910351498
# sleep_hours 0.23776798927196754
# nutrition_quality 0.27661681832315793
# activity_index 0.9135207799691556
# smokes -1.8496816410516121
# gender 0.8541863746674041

# %%
X
# Out:
#       age  height_cm  weight_kg  heart_rate  blood_pressure  sleep_hours  \
# 0      56        152         65        69.6           117.0     7.513315
# 1      69        186         95        60.8           114.8     7.500000
# 2      46        192        103        61.4           116.4     7.513315
# 3      32        189         83        60.2           130.1     7.000000
# 4      60        175         99        58.1           115.8     8.000000
# ...   ...        ...        ...         ...             ...          ...
# 1995   52        173         98        60.7           106.1     7.513315
# 1996   61        186         74        51.4           123.8     9.400000
# 1997   77        198         89        76.7           103.6     8.300000
# 1998   62        190         63        80.7           115.9     6.700000
# 1999   51        166         78        89.3           101.8     8.300000
#
#       nutrition_quality  activity_index  smokes  gender
# 0                  2.37            3.97       0       0
# 1                  8.77            3.19       0       0
# 2                  8.20            2.03       0       0
# 3                  6.18            3.68       0       1
# 4                  9.95            4.83       1       0
# ...                 ...             ...     ...     ...
# 1995               1.54            3.25       1       1
# 1996               8.63            3.15       0       1
# 1997               1.98            3.36       1       1
# 1998               9.21            2.39       1       0
# 1999               4.42            1.02       1       1
#
# [2000 rows x 10 columns]

# %%
y
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 1995    1
# 1996    1
# 1997    0
# 1998    0
# 1999    0
# Name: is_fit, Length: 2000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(X_train.corr(), annot=True)
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(
    splitter="random",
    min_samples_split=20,
    min_samples_leaf=10,
    max_leaf_nodes=None,
    max_features=None,
    max_depth=15,
    criterion="entropy",
    class_weight=None,
    random_state=42
)

# %%
y=data["is_fit"]

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=15, min_samples_leaf=10,
#                        min_samples_split=20, random_state=42,
#                        splitter='random')

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
conMet=confusion_matrix(y_test,y_pred)
classification=classification_report(y_test,y_pred)

# %%
print("confusion matrix",conMet)
print("classification",classification)
# Out:
# confusion matrix [[231  63]
#  [ 84 122]]
# classification               precision    recall  f1-score   support
#
#            0       0.73      0.79      0.76       294
#            1       0.66      0.59      0.62       206
#
#     accuracy                           0.71       500
#    macro avg       0.70      0.69      0.69       500
# weighted avg       0.70      0.71      0.70       500

# %%
from sklearn.model_selection import GridSearchCV
params = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'splitter': ['best', 'random'],
    'max_depth': [1, 2, 3, 4, 5],
    'max_features': [None, 'sqrt', 'log2']
}
grid=GridSearchCV(DecisionTreeClassifier(), params, cv=5, scoring='accuracy')
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
grid.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': None,
#  'splitter': 'random'}

# %%
grid.best_score_
# Out:
# np.float64(0.7306666666666667)

# %%
"""from sklearn.model_selection import RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier
import numpy as np

params = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 3, 5, 7, 10, 15],
    'max_features': [None, 'sqrt', 'log2'],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 4, 10],
    'max_leaf_nodes': [None, 10, 20, 50, 100],
    'class_weight': [None, 'balanced']
}

random_search = RandomizedSearchCV(
    DecisionTreeClassifier(random_state=42),
    param_distributions=params,
    n_iter=30,   # try 30 random combos instead of all
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    random_state=42
)

random_search.fit(X_train, y_train)

print("Best Params:", random_search.best_params_)
print("Best Score:", random_search.best_score_)
"""
# Out:
# 'from sklearn.model_selection import RandomizedSearchCV\nfrom sklearn.tree import DecisionTreeClassifier\nimport numpy as np\n\nparams = {\n    \'criterion\': [\'gini\', \'entropy\', \'log_loss\'],\n    \'splitter\': [\'best\', \'random\'],\n    \'max_depth\': [None, 3, 5, 7, 10, 15],\n    \'max_features\': [None, \'sqrt\', \'log2\'],\n    \'min_samples_split\': [2, 5, 10, 20],\n    \'min_samples_leaf\': [1, 2, 4, 10],\n    \'max_leaf_nodes\': [None, 10, 20, 50, 100],\n    \'class_weight\': [None, \'balanced\']\n}\n\nrandom_search = RandomizedSearchCV(\n    DecisionTreeClassifier(random_state=42),\n    param_distributions=params,\n    n_iter=30,   # try 30 random combos instead of all\n    cv=5,\n    scoring=\'accuracy\',\n    n_jobs=-1,\n    random_state=42\n)\n\nrandom_search.fit(X_train, y_train)\n\nprint("Best Params:", random_search.best_params_)\nprint("Best Score:", random_search.best_score_)\n'

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
pred=grid.predict(X_test)

# %%
print("accuracy",accuracy_score(y_test,pred))
# Out:
# accuracy 0.724

# %%
X_train.columns
# Out:
# Index(['age', 'height_cm', 'weight_kg', 'heart_rate', 'blood_pressure',
#        'sleep_hours', 'nutrition_quality', 'activity_index', 'smokes',
#        'gender'],
#       dtype='object')

# %%
prediction =grid.predict(new_data)
if prediction[0]==0:
    print("you are not fit")
else:
    print("you are fit")
# Out:
# you are fit

# %%
test_data = {
    'age': [46],
    'height_cm': [192],
    'weight_kg': [103],
    'heart_rate': [61.4],
    'blood_pressure': [116.4],
    'sleep_hours': [7.513315],
    'nutrition_quality': [8.20],
    'activity_index': [2.03],
    'smokes': [0],
    'gender': [0]
}
								

# Convert to DataFrame
new_data = pd.DataFrame(test_data)


# Predict using your trained model
prediction = grid.predict(new_data)
print("Predicted is_fit:", "Fit" if prediction[0] == 1 else "Not Fit")
# Out:
# Predicted is_fit: Fit

# %%
import pickle

pickle.dump(grid,open("model.pkl","wb"))
