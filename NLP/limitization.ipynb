# %%
from nltk.stem import WordNetLemmatizer

# %%
lematizer=WordNetLemmatizer()

# %%
lematizer.lemmatize("going",pos='v')
# Out:
# 'go'

# %%
import nltk

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
words=['eating','eats','writing','writes','programming',"programs","history","finally","finalize"]

# %%
for word in words:
    print(word+"--->"+lematizer.lemmatize(word,pos='v'))
# Out:
# eating--->eat
# eats--->eat
# writing--->write
# writes--->write
# programming--->program
# programs--->program
# history--->history
# finally--->finally
# finalize--->finalize

# %%
lematizer.lemmatize("goes")
# Out:
# 'go'

# %%
lematizer.lemmatize("fairly",pos='r')
# Out:
# 'fairly'
