# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp313-cp313-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from gensim) (2.2.6)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from gensim) (1.16.0)
# Collecting smart_open>=1.8.1 (from gensim)
#   Downloading smart_open-7.4.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart_open>=1.8.1->gensim)
#   Downloading wrapt-2.0.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Downloading gensim-4.4.0-cp313-cp313-win_amd64.whl (24.4 MB)
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    --- ------------------------------------ 2.4/24.4 MB 15.3 MB/s eta 0:00:02
#    --------- ------------------------------ 5.5/24.4 MB 14.5 MB/s eta 0:00:02
#    ------------ --------------------------- 7.9/24.4 MB 14.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 10.7/24.4 MB 14.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 14.2/24.4 MB 14.0 MB/s eta 0:00:01
#    --------------------------- ------------ 16.5/24.4 MB 13.7 MB/s eta 0:00:01
#    ------------------------------- -------- 19.1/24.4 MB 13.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.8/24.4 MB 13.5 MB/s eta 0:00:01
#    ---------------------------------------  24.4/24.4 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 24.4/24.4 MB 13.1 MB/s  0:00:01
# Downloading smart_open-7.4.0-py3-none-any.whl (63 kB)
# Downloading wrapt-2.0.0-cp313-cp313-win_amd64.whl (60 kB)
# Installing collected packages: wrapt, smart_open, gensim
#
#    ---------------------------------------- 0/3 [wrapt]
#    ------------- -------------------------- 1/3 [smart_open]
#    ------------- -------------------------- 1/3 [smart_open]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    ---------------------------------------- 3/3 [gensim]
#
# Successfully installed gensim-4.4.0 smart_open-7.4.0 wrapt-2.0.0

# %%
import gensim

# %%
from gensim.models import Word2Vec,KeyedVectors

# %%
import gensim.downloader as api
wv = api.load("word2vec-google-news-300")
# Out:
# [========================--------------------------] 48.4% 804.0/1662.8MB downloaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import gensim.downloader as api
# ----> 2 wv = api.load("word2vec-google-news-300")
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\gensim\downloader.py:496, in load(name, return_path)
#     494 path = os.path.join(folder_dir, file_name)
#     495 if not os.path.exists(folder_dir):
# --> 496     _download(name)
#     498 if return_path:
#     499     return path
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\gensim\downloader.py:396, in _download(name)
#     394 fname = "{fname}.gz".format(fname=name)
#     395 dst_path = os.path.join(tmp_dir, fname)
# --> 396 urllib.urlretrieve(url_data, dst_path, reporthook=_progress)
#     397 if _calculate_md5_checksum(dst_path) == _get_checksum(name):
#     398     sys.stdout.write("\n")
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:247, in urlretrieve(url, filename, reporthook, data)
#     245             blocknum += 1
#     246             if reporthook:
# --> 247                 reporthook(blocknum, bs, size)
#     249 if size >= 0 and read < size:
#     250     raise ContentTooShortError(
#     251         "retrieval incomplete: got only %i out of %i bytes"
#     252         % (read, size), result)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\gensim\downloader.py:129, in _progress(chunks_downloaded, chunk_size, total_size, part, total_parts)
#     122 if total_parts == 1:
#     123     sys.stdout.write(
#     124         '\r[%s] %s%s %s/%sMB downloaded' % (
#     125             bar, percent_downloaded, "%",
#     126             round(size_downloaded / (1024 * 1024), 1),
#     127             round(float(total_size) / (1024 * 1024), 1))
#     128     )
# --> 129     sys.stdout.flush()
#     130 else:
#     131     sys.stdout.write(
#     132         '\r Part %s/%s [%s] %s%s %s/%sMB downloaded' % (
#     133             part + 1, total_parts, bar, percent_downloaded, "%",
#     134             round(size_downloaded / (1024 * 1024), 1),
#     135             round(float(total_size) / (1024 * 1024), 1))
#     136     )
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\iostream.py:604, in OutStream.flush(self)
#     593 """trigger actual zmq send
#     594
#     595 send will happen in the background thread
#     596 """
#     597 if (
#     598     self.pub_thread
#     599     and self.pub_thread.thread is not None
#    (...)    602 ):
#     603     # request flush on the background thread
# --> 604     self.pub_thread.schedule(self._flush)
#     605     # wait for flush to actually get through, if we can.
#     606     evt = threading.Event()
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\iostream.py:267, in IOPubThread.schedule(self, f)
#     265     self._events.append(f)
#     266     # wake event thread (message content is ignored)
# --> 267     self._event_pipe.send(b"")
#     268 else:
#     269     f()
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\zmq\sugar\socket.py:698, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     691         data = zmq.Frame(
#     692             data,
#     693             track=track,
#     694             copy=copy or None,
#     695             copy_threshold=self.copy_threshold,
#     696         )
#     697     data.group = group
# --> 698 return super().send(data, flags=flags, copy=copy, track=track)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\zmq\backend\cython\_zmq.py:1137, in zmq.backend.cython._zmq.Socket.send()
#    1134     rc: C.int = zmq_leave(self.handle, group)
#    1135     _check_rc(rc)
# -> 1137 def send(self, data, flags=0, copy: bint = True, track: bint = False):
#    1138     """
#    1139     Send a single zmq message frame on this socket.
#    1140
#    (...)   1177
#    1178     """
#    1179     _check_closed(self)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\zmq\backend\cython\_zmq.py:1185, in zmq.backend.cython._zmq.Socket.send()
#    1182     raise TypeError("unicode not allowed, use send_string")
#    1184 if copy and not isinstance(data, Frame):
# -> 1185     return _send_copy(self.handle, data, flags)
#    1186 else:
#    1187     if isinstance(data, Frame):
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\zmq\backend\cython\_zmq.py:1453, in zmq.backend.cython._zmq._send_copy()
#    1451     rc = zmq_msg_send(address(msg), handle, flags)
#    1452 try:
# -> 1453     _check_rc(rc)
#    1454 except InterruptedSystemCall:
#    1455     continue
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\zmq\backend\cython\_zmq.py:176, in zmq.backend.cython._zmq._check_rc()
#     171 """internal utility for checking zmq return condition
#     172
#     173 and raising the appropriate Exception class
#     174 """
#     175 errno: C.int = _zmq_errno()
# --> 176 PyErr_CheckSignals()
#     177 if errno == 0 and not error_without_errno:
#     178     return 0
#
# KeyboardInterrupt:
